# %%
#ejercicio 2 tema 2-3
nombre_usuario = input("El nombre del usuario es:")
print(nombre_usuario.upper() + " tiene " + str(len(nombre_usuario)) + " letras")
# Out:
# El nombre del usuario es:Marta Moya echevarria
# MARTA MOYA ECHEVARRIA tiene 21 letras

# %%
#ejecicio 1 tema 2-3
mi_nombre = input()
print(mi_nombre)
print(mi_nombre*3)
print(mi_nombre.upper())
print(mi_nombre.lower())
print(mi_nombre.title())
# Out:
# paco carmona izquierdo
# paco carmona izquierdo
# paco carmona izquierdopaco carmona izquierdopaco carmona izquierdo
# PACO CARMONA IZQUIERDO
# paco carmona izquierdo
# Paco Carmona Izquierdo

# %%
#ejercicio 3 tema 2-3
prefijo = int(input("el codigo del pais es:"))
numero = int(input("el numero de telefono es:"))
extension = int(input("la extension es:"))
print(str(numero) + "-" + str(extension))
# Out:
# el codigo del pais es:+34
# el numero de telefono es:675551112
# la extension es:51
# 675551112-51

# %%
#ejercicio 4 tema 2-3
frase = input("Introduce una frase: ")
vocal = input("Introduce una vocal:  ")
print(frase.replace(vocal, vocal.upper()))
# Out:
# Introduce una frase: La casa es rosa
# Introduce una vocal:  a
# LA cAsA es rosA

# %%
#ejercicio 5 tema 2-3
dividendo = float(input("Introduce el dividendo: "))
divisor = float(input("Introduce el divisior: "))
if divisor == 0:
    print("¡Error! No se puede dividir por 0.")
else:
    print(dividendo/divisor)
# Out:
# Introduce el dividendo: 3552
# Introduce el divisior: 518
# 6.857142857142857

# %%
#ejercicio 6 tema2-3
entero = int(input("Introduce un numero entero:"))
n = entero%2
if n == 0:
  print("el numero es par")
else:
  print("el numero es impar")
# Out:
# Introduce un numero entero:5
# el numero es impar

# %%
#ejercicio 7 tema 2-3
renta = int(input("¿cuanto gana anualmente? "))
if renta < 10000:
  print("usted pagara 5%")
elif renta >= 10000 and renta < 20000:
  print("usted pagara 15%")
elif renta >= 20000 and renta < 35000:
  print("usted pagara 20%")
elif renta >= 35000 and renta < 60000:
  print("usted pagara 30%")
else:
  print("usted pagar 45%")
# Out:
# ¿cuanto gana anualmente? 9000
# usted pagara 5%

# %%
#ejercicio 8 tema 2-3
edad = int(input("¿Cuántos años tiene? "))
if edad < 4 :
  print("La entrada seran 4$")
elif edad >= 5 and edad < 18 :
  print("La entrada sera 5$")
else:
  print("la entrada sera 10$")
# Out:
# ¿Cuántos años tiene? 18
# la entrada sera 10$

# %%
usuario = input("Escribe tu usuario:")
rendimiento = float(input("¿Cual ha sido su rendimiento? "))
if rendimiento == 0.0 and rendimiento == 0.4:
  print(" el usuario " + usuario +" ha tenido un rendimiento de " + str(rendimiento) + " y recibira " + 2400*rendimiento)
else:
  print("error del sistema")
# Out:
# Escribe tu usuario:paco
# ¿Cual ha sido su rendimiento? 0.4
# error del sistema

# %%
#ejercicio 9 tema 2-3
bonificacion = 2400
inaceptable = 0
aceptable = 0.4
meritorio = 0.6
puntos = float(input("Introduce tu puntuación: "))

if puntos == inaceptable:
    nivel = "Inaceptable"
elif puntos == aceptable:
    nivel = "Aceptable"
elif puntos >= 0.6:
    nivel = "Meritorio"
else:
    nivel = ""

if nivel == "":
    print("Esta puntuación no es válida")
else:
    print("Tu nivel de rendimiento es  " + nivel)
    print("Te corresponde cobrar " + str(puntos * bonificacion))
# Out:
# Introduce tu puntuación: 0.7
# Tu nivel de rendimiento es  Meritorio
# Te corresponde cobrar 1680.0

# %%
#ejercicio 10 tema 2y3
pizza = int(input("si desea pizza vegetariana teclee 1, si desea pizza no vegetaria teclee 2:"))
if pizza == 1:
  print("ingredientes de la pizza vegetaria son 1 tofu 2 pimiento" )
  ingrediente = input("introduce el ingrediente:")
  if ingrediente == "1":
    print("pizza vegetariana con tomate, mozarella y pimiento")
  elif ingrediente == "2":
    print("pizza vegetariana con tomate, mozarella y tofu")
  else:
    print("error")
  
elif pizza == 2:
  print("Ingredientes de pizzas no vegetarianas: 1.Peperoni 2.Jamón 3.Salmón")
  ingrediente = input("Introduce el ingrediente que deseas: ")
  if ingrediente == "1":
    print("Pizza no vegetarina con mozarrella, tomate y peperoni")
  elif ingrediente == "2":
    print("Pizza no vegetarina con mozarrella, tomate y jamon")
  elif ingrediente == "3":
    print("Pizza no vegetarina con mozarrella, tomate y salmon")
  else:
    print("error")
else:
  print("error")
# Out:
# si desea pizza vegetariana teclee 1, si desea pizza no vegetaria teclee 2:2
# Ingredientes de pizzas no vegetarianas: 1.Peperoni 2.Jamón 3.Salmón
# Introduce el ingrediente que deseas: 2
# Pizza no vegetarina con mozarrella, tomate y jamon

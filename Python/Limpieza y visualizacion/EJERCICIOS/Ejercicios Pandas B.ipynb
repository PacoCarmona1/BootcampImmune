# %% [markdown]
# # Copa del mundo
#
# Descarga el archivo csv en Canvas llamado world_cup.csv

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/Paco/Downloads/world_cup.csv')
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %% [markdown]
# ## Asígnalo a una variable llamada df.

# %%
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %% [markdown]
# ## Divide el marco de datos desde la columna "Host" hasta la columna "Champion".

# %%
#df.loc[:, 'Host':'Champion']
df2 = df.loc[:, 'Host':'Champion']
df2
# Out:
#                      Host  Teams      Champion
# 0                   Qatar     32           NaN
# 1                  Russia     32        France
# 2                  Brazil     32       Germany
# 3            South Africa     32         Spain
# 4                 Germany     32         Italy
# 5   Korea Republic, Japan     32        Brazil
# 6                  France     32        France
# 7           United States     24        Brazil
# 8                   Italy     24  West Germany
# 9                  Mexico     24     Argentina
# 10                  Spain     24         Italy
# 11              Argentina     16     Argentina
# 12                Germany     16  West Germany
# 13                 Mexico     16        Brazil
# 14                England     16       England
# 15                  Chile     16        Brazil
# 16                 Sweden     16        Brazil
# 17            Switzerland     16       Germany
# 18                 Brazil     15       Uruguay
# ...

# %% [markdown]
# ## Crea una función lambda poner en mayusculas las cadenas.

# %%
mayusculas = lambda string: string.upper()

# %% [markdown]
# ### Usando la funcion anterior aplícala a la columna Host

# %%
df1 =df['Host'].apply(mayusculas)
df1
# Out:
# 0                     QATAR
# 1                    RUSSIA
# 2                    BRAZIL
# 3              SOUTH AFRICA
# 4                   GERMANY
# 5     KOREA REPUBLIC, JAPAN
# 6                    FRANCE
# 7             UNITED STATES
# 8                     ITALY
# 9                    MEXICO
# 10                    SPAIN
# 11                ARGENTINA
# 12                  GERMANY
# 13                   MEXICO
# 14                  ENGLAND
# 15                    CHILE
# 16                   SWEDEN
# 17              SWITZERLAND
# 18                   BRAZIL
# 19                   FRANCE
# 20                    ITALY
# 21                  URUGUAY
# Name: Host, dtype: object

# %% [markdown]
# ### Ahora aplícala para la columna Teams y comenta el resultado

# %%
df['Teams'] = df['Teams'].apply(mayusculas)

# No se puede aplicar por que es un objeto int asi que no se puede aplicar a numeros
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Teams'] = df['Teams'].apply(mayusculas)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...

# %% [markdown]
# ## Muestra los últimos 8 resultados del set de datos

# %%
df.tail(8)
# Out:
#            Host  Teams Champion
# 14      England     16  England
# 15        Chile     16   Brazil
# 16       Sweden     16   Brazil
# 17  Switzerland     16  Germany
# 18       Brazil     15  Uruguay
# 19       France     16    Italy
# 20        Italy     16    Italy
# 21      Uruguay     13  Uruguay

# %% [markdown]
# ## Te has fijado el dataset original no ha modificado la columna Host? Por qué ocurre esto?

# %% [markdown]
# ## Crea una columna que se llame Favoritos e introduce una serie de 3 filas con 'Si'y 5 con 'No'.

# %%
favoritos = pd.Series(['Si', 'Si', 'Si', 'No', 'No', 'No', 'No', 'No'])
df['Favoritos'] = favoritos
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  QATAR     32           NaN             NaN
# 1   2018                 RUSSIA     32        France         Croatia
# 2   2014                 BRAZIL     32       Germany       Argentina
# 3   2010           SOUTH AFRICA     32         Spain     Netherlands
# 4   2006                GERMANY     32         Italy          France
# 5   2002  KOREA REPUBLIC, JAPAN     32        Brazil         Germany
# 6   1998                 FRANCE     32        France          Brazil
# 7   1994          UNITED STATES     24        Brazil           Italy
# 8   1990                  ITALY     24  West Germany       Argentina
# 9   1986                 MEXICO     24     Argentina    West Germany
# 10  1982                  SPAIN     24         Italy    West Germany
# 11  1978              ARGENTINA     16     Argentina     Netherlands
# 12  1974                GERMANY     16  West Germany     Netherlands
# ...

# %% [markdown]
# ## Crea una función que seleccione los mundiales favoritos y devuelva 'BluRay' como resultado para los que hay que grabar y 'VHS' para los que no son favoritos, después crea una columna que se llame Grabar donde irán los resultados de l fórmula anterior.

# %%
df['Grabar'] = df.apply(lambda x: 'BluRay' if x['Favoritos'] == 'Si' else 'VHS', axis=1)
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  QATAR     32           NaN             NaN
# 1   2018                 RUSSIA     32        France         Croatia
# 2   2014                 BRAZIL     32       Germany       Argentina
# 3   2010           SOUTH AFRICA     32         Spain     Netherlands
# 4   2006                GERMANY     32         Italy          France
# 5   2002  KOREA REPUBLIC, JAPAN     32        Brazil         Germany
# 6   1998                 FRANCE     32        France          Brazil
# 7   1994          UNITED STATES     24        Brazil           Italy
# 8   1990                  ITALY     24  West Germany       Argentina
# 9   1986                 MEXICO     24     Argentina    West Germany
# 10  1982                  SPAIN     24         Italy    West Germany
# 11  1978              ARGENTINA     16     Argentina     Netherlands
# 12  1974                GERMANY     16  West Germany     Netherlands
# ...

# %% [markdown]
# ## Eleva la columna de equipos al cuadrado

# %%
df['Teams'] = df['Teams']**2
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  QATAR   4096           NaN             NaN
# 1   2018                 RUSSIA   4096        France         Croatia
# 2   2014                 BRAZIL   4096       Germany       Argentina
# 3   2010           SOUTH AFRICA   4096         Spain     Netherlands
# 4   2006                GERMANY   4096         Italy          France
# 5   2002  KOREA REPUBLIC, JAPAN   4096        Brazil         Germany
# 6   1998                 FRANCE   4096        France          Brazil
# 7   1994          UNITED STATES   2304        Brazil           Italy
# 8   1990                  ITALY   2304  West Germany       Argentina
# 9   1986                 MEXICO   2304     Argentina    West Germany
# 10  1982                  SPAIN   2304         Italy    West Germany
# 11  1978              ARGENTINA   1024     Argentina     Netherlands
# 12  1974                GERMANY   1024  West Germany     Netherlands
# ...

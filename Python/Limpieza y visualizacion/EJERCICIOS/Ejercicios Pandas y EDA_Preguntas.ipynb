# %%
import pandas as pd
import numpy as np
from datetime import datetime
import cufflinks as cf
import plotly.offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# 1. Generar un DataFrame con los datos de los fichero:
#
# 2. Filtrar las columnas del DataFrame para quedarse con las columnas 'Unique Key', 'Created Date', 'Closed Date', 'Complaint Type', 'Borough'
#
# 3. Añade una nueva columna llamada 'Year' al DataFrame, que contenga solo el año de la fecha en que se creó la queja (basado en la columna 'Created Date').
#
# 4. Añadir una columna con la duración de la queja (desde la creación hasta la fecha de cierre).
#
# 5. Eliminar las filas con duraciones de quejas no válidas y ordenar el DataFrame por 'Borough' y 'Complaint Duration'
#
# 6. Mostrar por pantalla los distritos y los tipos de quejas disponibles en el DataFrame.
#
# 7. Crear una función que reciba un distrito, un tipo de queja y devuelva la duración promedio de ese tipo de queja en el distrito dado.
#
# 8. Mostrar un resumen descriptivo (mínimo, máximo, media, etc.) para cada tipo de queja.
#
# 9. Mostrar un resumen descriptivo para cada tipo de queja por distritos.
#
# 10. Crear una función que reciba un distrito y devuelva un resumen descriptivo de las duraciones de quejas de ese distrito.
#
# 11. Crear una función que devuelva las duraciones promedio de quejas mensuales de un distrito dado para todos los tipos de quejas.
#
# 12. Crear una función que reciba un tipo de queja y devuelva un DataFrame con las duraciones promedio de quejas mensuales de los distintos distritos.
#
# 13. ¿Cuál es la duración media de las quejas de todos los tipos de quejas para el distrito "MANHATTAN"?
#
# 14. ¿Cómo es la distribución de las quejas en cada distrito?
#
# 15. ¿Cuál es el número total de quejas en cada mes?
#
# 16. ¿Cuál es el tipo de queja más común?
#
# 17. ¿Cuál es la duración media de las quejas por tipo de queja?

# %% [markdown]
# # 1. Generar un DataFrame con los datos de los fichero:

# %%
quejas = pd.read_csv('/Users/Paco/Downloads/311_Service_Requests__2019-04-01_.csv')
quejas
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 0       42108723  04/01/2019 08:00:16 AM  04/01/2019 08:59:56 AM   NYPD
# 1       42104638  04/01/2019 08:00:19 AM  05/10/2019 07:19:18 PM    DOT
# 2       42107348  04/01/2019 08:00:45 AM  04/02/2019 08:48:15 PM    HPD
# 3       42112707  04/01/2019 08:01:00 AM  04/05/2019 12:00:00 PM   DSNY
# 4       42112239  04/01/2019 08:01:18 AM  04/03/2019 02:10:00 AM    HPD
# ...          ...                     ...                     ...    ...
# 5964    42107379  04/01/2019 07:59:09 PM  04/04/2019 02:09:57 AM    HPD
# 5965    42110686  04/01/2019 07:59:11 PM  04/01/2019 11:59:49 PM   NYPD
# 5966    42112169  04/01/2019 07:59:15 PM  06/06/2019 05:19:05 PM    TLC
# 5967    42111932  04/01/2019 07:59:17 PM  04/01/2019 11:46:35 PM   NYPD
# 5968    42109440  04/01/2019 07:59:54 PM  04/01/2019 10:10:45 PM   NYPD
#
#                                             Agency Name  \
# 0                       New York City Police Department
# 1                          Department of Transportation
# 2     Department of Housing Preservation and Develop...
# 3                              Department of Sanitation
# 4     Department of Housing Preservation and Develop...
# ...                                                 ...
# 5964  Department of Housing Preservation and Develop...
# 5965                    New York City Police Department
# 5966                      Taxi and Limousine Commission
# 5967                    New York City Police Department
# 5968                    New York City Police Department
#
#                   Complaint Type                        Descriptor  \
# 0               Blocked Driveway                    Partial Access
# 1              Highway Condition                Graffiti - Highway
# 2                 HEAT/HOT WATER                   ENTIRE BUILDING
# 3           Sanitation Condition  15 Street Cond/Dump-Out/Drop-Off
# 4                 HEAT/HOT WATER                   ENTIRE BUILDING
# ...                          ...                               ...
# 5964              HEAT/HOT WATER                   ENTIRE BUILDING
# 5965         Noise - Residential                  Loud Music/Party
# 5966  For Hire Vehicle Complaint                  Driver Complaint
# 5967            Derelict Vehicle                With License Plate
# 5968         Noise - Residential                  Banging/Pounding
#
#                    Location Type  Incident Zip               Incident Address  \
# 0                Street/Sidewalk       11373.0           51-06 HILLYER STREET
# 1                        Highway           NaN                            NaN
# 2           RESIDENTIAL BUILDING       11232.0                  4024 5 AVENUE
# 3                         Street       11215.0                   494 5 AVENUE
# 4           RESIDENTIAL BUILDING       10468.0             2645 MORRIS AVENUE
# ...                          ...           ...                            ...
# 5964        RESIDENTIAL BUILDING       10453.0  2015 DR M L KING JR BOULEVARD
# 5965  Residential Building/House       10026.0         71 MALCOLM X BOULEVARD
# 5966                      Street       10002.0            153 CHRYSTIE STREET
# 5967             Street/Sidewalk       11206.0                210 COOK STREET
# 5968  Residential Building/House       10455.0               706 BROOK AVENUE
#
#       ... Vehicle Type Taxi Company Borough Taxi Pick Up Location  \
# 0     ...          NaN                  NaN                   NaN
# 1     ...          NaN                  NaN                   NaN
# 2     ...          NaN                  NaN                   NaN
# 3     ...          NaN                  NaN                   NaN
# 4     ...          NaN                  NaN                   NaN
# ...   ...          ...                  ...                   ...
# 5964  ...          NaN                  NaN                   NaN
# 5965  ...          NaN                  NaN                   NaN
# 5966  ...          NaN                  NaN                   NaN
# 5967  ...          NaN                  NaN                   NaN
# 5968  ...          NaN                  NaN                   NaN
#
#      Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                    NaN                      NaN       NaN
# 1        Clearview Expwy        North/Bronx Bound   Roadway
# 2                    NaN                      NaN       NaN
# 3                    NaN                      NaN       NaN
# 4                    NaN                      NaN       NaN
# ...                  ...                      ...       ...
# 5964                 NaN                      NaN       NaN
# 5965                 NaN                      NaN       NaN
# 5966                 NaN                      NaN       NaN
# 5967                 NaN                      NaN       NaN
# 5968                 NaN                      NaN       NaN
#
#                                 Bridge Highway Segment   Latitude  Longitude  \
# 0                                                  NaN  40.736906 -73.885645
# 1     35th Ave (Exit 6A) - Willets Point Blvd (Exit 7)        NaN        NaN
# 2                                                  NaN  40.650530 -74.004685
# 3                                                  NaN  40.667561 -73.987661
# 4                                                  NaN  40.866495 -73.896749
# ...                                                ...        ...        ...
# 5964                                               NaN  40.855322 -73.910742
# 5965                                               NaN  40.800504 -73.950806
# 5966                                               NaN  40.720395 -73.992687
# 5967                                               NaN  40.703156 -73.934973
# 5968                                               NaN  40.819222 -73.912484
#
#                                       Location
# 0      (40.73690600974706, -73.88564459165903)
# 1                                          NaN
# 2      (40.65052993939405, -74.00468491123993)
# 3      (40.66756073325308, -73.98766111858107)
# 4       (40.8664950875277, -73.89674905894428)
# ...                                        ...
# 5964  (40.855322106090505, -73.91074151524113)
# 5965  (40.800504000346805, -73.95080595870716)
# 5966   (40.72039520845853, -73.99268748469251)
# 5967   (40.70315643455786, -73.93497258548766)
# 5968   (40.81922225156659, -73.91248439243729)
#
# [5969 rows x 39 columns]

# %% [markdown]
# # 2. Filtrar las columnas del DataFrame para quedarse con las columnas 'Unique Key', 'Created Date', 'Closed Date', 'Complaint Type', 'Borough'

# %% [markdown]
# # 3. Añade una nueva columna llamada 'Year' al DataFrame, que contenga solo el año de la fecha en que se creó la queja (basado en la columna 'Created Date').

# %% [markdown]
# # 4. Añadir una columna con la duración de la queja (desde la creación hasta la fecha de cierre).

# %% [markdown]
# # 5. Eliminar las filas con duraciones de quejas no válidas y ordenar el DataFrame por 'Borough' y 'Complaint Duration'

# %% [markdown]
# # 6. Mostrar por pantalla los distritos y los tipos de quejas disponibles en el DataFrame.

# %% [markdown]
# # 7. Crear una función que reciba un distrito, un tipo de queja y devuelva la duración promedio de ese tipo de queja en el distrito dado.

# %% [markdown]
# # 8. Mostrar un resumen descriptivo (mínimo, máximo, media, etc.) para cada tipo de queja.

# %% [markdown]
# # 9. Mostrar un resumen descriptivo para cada tipo de queja por distritos.

# %% [markdown]
# # 10. Crear una función que reciba un distrito y devuelva un resumen descriptivo de las duraciones de quejas de ese distrito.

# %% [markdown]
# # 11. Crear una función que devuelva las duraciones promedio de quejas mensuales de un distrito dado para todos los tipos de quejas.

# %% [markdown]
# # 12. Crear una función que reciba un tipo de queja y devuelva un DataFrame con las duraciones promedio de quejas mensuales de los distintos distritos.

# %% [markdown]
# # 13. ¿Cuál es la duración media de las quejas de todos los tipos de quejas para el distrito "MANHATTAN"?

# %% [markdown]
# # 14. ¿Cómo es la distribución de las quejas en cada distrito?

# %% [markdown]
# # 15. ¿Cuál es el número total de quejas en cada mes?

# %% [markdown]
# # 16. ¿Cuál es el tipo de queja más común?

# %% [markdown]
# # 17. ¿Cuál es la duración media de las quejas por tipo de queja?

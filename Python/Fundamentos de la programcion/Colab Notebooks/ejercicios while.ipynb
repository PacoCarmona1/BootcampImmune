# %%
num = int(input("Ingrese un número para calcular su factorial: "))
fact = 1
i = 1

while i <= num:
    fact *= i
    i += 1

print("El factorial de " + str(num) + " es: " + str(fact))
# Out:
# Ingrese un número para calcular su factorial: 5
# El factorial de 5 es: 120

# %%
suma = 0
cantidad = 0

numero = float(input("Introduce un número: "))

while numero != 0:

    suma += numero
    cantidad += 1 
    
    numero = float(input("Introduce otro número: "))
    
media = suma / cantidad

print("La suma de los números introducidos es:" + suma)
print("La media de los números introducidos es:" + media)
# Out:
# Introduce un número (introduce 0 para finalizar): 2
# Introduce otro número (introduce 0 para finalizar): 3
# Introduce otro número (introduce 0 para finalizar): 0
# La suma de los números introducidos es: 5.0
# La media de los números introducidos es: 2.5

# %%
letra= input("Introduce una letra:")
while letra != " ":
  if letra in  "AEIOUaeiuo":
    print("VOCAL")
    letra= input("Introduce una letra:")
    
  else:
    print("NOVOCAL")
    letra= input("Introduce una letra:")
print("has introducido un espacio")
# Out:
# Introduce una letra:"
# NOVOCAL
# Introduce una letra:
# has introducido un espacio

# %%
suma = 0

while suma <= 100:
  
  num = int(input("introduce un numero:"))

  suma = suma + num

print(str(suma))
# Out:
# introduce un numero:3
# introduce un numero:3
# introduce un numero:8
# introduce un numero:90
# 104

# %%
auto1 = 70
auto2 = 150

while auto1 != auto2:
  auto1 = auto1 + 1
  auto2 = auto2 - 1

print(auto1)
# Out:
# 110

# %%
ahorro = 0
print("La cantidad que queremos ahorrar es: 200")
dinero = float(input("qué cantidad quieres introducir: "))

if dinero < 0:
    print("Por favor, escribe una cantidad positiva")
else:
    while ahorro <= 200:
        ahorro = ahorro + dinero
        dinero = float(input("que cantidad quieres introducir: "))
    print("¡Objetivo conseguido! Has ahorrado: " + str(ahorro))
# Out:
# La cantidad que queremos ahorrar es: 200
# qué cantidad quieres introducir: 200
# que cantidad quieres introducir: 2
# que cantidad quieres introducir: 2
# ¡Objetivo conseguido! Has ahorrado: 202.0

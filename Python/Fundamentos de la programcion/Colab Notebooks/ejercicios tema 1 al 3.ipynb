# %%
horas = float(input("cuantas horas has trabajado"))
coste = float(input("cuanto cobras por hora"))
total = horas*coste
print(str(total))
# Out:
# cuantas horas has trabajado10
# cuanto cobras por hora10
# 100.0

# %%
n = int(input("ingrese n:"))
suma_total = n * (n+1)/2
print(int(suma_total))
# Out:
# ingrese n:20
# 210

# %%
peso = float(input("peso es:"))
altura = float(input("altura es"))
imc = peso/(altura**2)
print(round(imc,2))
# Out:
# peso es:72.1
# altura es1.75
# 23.54

# %%
n = int(input())
m = int(input())
cociente = n//m
resto = n%m
print(str(n) + " entre " + str(m) + " da un cociente " + str(cociente) + " y un resto " + str(resto))
# Out:
# 7
# 4
# 7 entre 4 da un cociente 1 y un resto 3

# %%
len("hola Python")
# Out:
# 11

# %%
"hola mundo". split()
# Out:
# ['hola', 'mundo']

# %%
print("paco"*3)
# Out:
# pacopacopaco

# %%
mi_nombre = input()
print(mi_nombre)
print(mi_nombre*3)
print(mi_nombre.upper())
print(mi_nombre.lower())
print(mi_nombre.title())
# Out:
# paco carmona izquierdo
# paco carmona izquierdo
# paco carmona izquierdopaco carmona izquierdopaco carmona izquierdo
# PACO CARMONA IZQUIERDO
# paco carmona izquierdo
# Paco Carmona Izquierdo

# %%
texto = "paco es el mejor"
print(texto)
print(texto.replace("es","era"))
# Out:
# paco es el mejor
# paco era el mejor

# %%
x = (1,2,3,7,8,0)
print(max(x))
# Out:
# 8

# %%
n = int(input())
suma = n*(n+1)/2
print(int(suma))
# Out:
# 100
# 5050

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print("Paco")
# Out:
# Paco

# %%
mi_nombre = "Paco"
print(mi_nombre)
# Out:
# Paco

# %%
mi_nombre = input()
# Out:
# Paco

# %%
print (mi_nombre)
# Out:
# Paco

# %%
mi_nombre = "Paco"
mi_apellido = "Carmona"
mi_nombre_completo = mi_nombre + " " + mi_apellido
print(mi_nombre_completo)
# Out:
# Paco Carmona

# %%
mi_nombre = input()
mi_apellido1 = input()
mi_apellido2 = input()
# Out:
# Paco
# Carmona
# Izquierdo

# %%
print(mi_nombre +" "+ mi_apellido1 +" "+ mi_apellido2)
# Out:
# Paco Carmona Izquierdo

# %%
mi_nombre = input()
# Out:
# Paco

# %%
horas = float(input("cuantas horas has trabajado"))
coste = float(input("cuanto cobras por hora"))
total = horas*coste
print(str(total))
# Out:
# cuantas horas has trabajado10
# cuanto cobras por hora10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-413d402b4db1> in <module>
#       2 coste = float(input("cuanto cobras por hora"))
#       3 total = horas*coste
# ----> 4 print(str(total))
#
# TypeError: 'str' object is not callable

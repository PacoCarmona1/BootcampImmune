# %% [markdown]
# # Tema 3. Pandas II 08.05.23

# %% [markdown]
# ## 1. Creacion de un DataFrame a partir de un diccionario de listas

# %%
import pandas as pd
import numpy as np

# %%
# Crear un DataFrame a partir de un diccionario de listas

datos = {'nombre':['Maria','Ignacion','Fatima','Ricardo'],'Notas':[10,10,10,10]}

df= pd.DataFrame(datos)
df
# Out:
#      nombre  Notas
# 0     Maria     10
# 1  Ignacion     10
# 2    Fatima     10
# 3   Ricardo     10

# %%
# Crea un DataFrame a partir de una lista de diccionarios

#df2 = pd.DataFrame([{'Nombre':'Maria','Notas':10},{'Nombre':'ignacio','Notas':10},{'Nombre':'Paco','Notas':10},{'Nombre':'Ricardo','Notas':10}])
df2 = pd.DataFrame([{'Maria',10},{'Ignacio',10},{'Paco',10},{'Ricardo',10}],columns = ['nombre','notas'])
df2
# Out:
#    nombre    notas
# 0      10    Maria
# 1      10  Ignacio
# 2      10     Paco
# 3      10  Ricardo

# %%
# Crear un DataFrame a partir de un array

df3 = pd.DataFrame(np.ramdon.rand)#no terminado

# %% [markdown]
# # Lectura de Ficheros

# %%
df4 = pd.read_csv('/Users/Paco/Downloads/world_cup.csv')
df4
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           22 non-null     int64
#  1   Host           22 non-null     object
#  2   Teams          22 non-null     int64
#  3   Champion       21 non-null     object
#  4   Runner-Up      21 non-null     object
#  5   TopScorrer     21 non-null     object
#  6   Attendance     22 non-null     int64
#  7   AttendanceAvg  22 non-null     int64
#  8   Matches        22 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.7+ KB

# %%
df4.dtypes
# Out:
# Year              int64
# Host             object
# Teams             int64
# Champion         object
# Runner-Up        object
# TopScorrer       object
# Attendance        int64
# AttendanceAvg     int64
# Matches           int64
# dtype: object

# %%
df4.head()
# Out:
#    Year          Host  Teams Champion    Runner-Up  \
# 0  2022         Qatar     32      NaN          NaN
# 1  2018        Russia     32   France      Croatia
# 2  2014        Brazil     32  Germany    Argentina
# 3  2010  South Africa     32    Spain  Netherlands
# 4  2006       Germany     32    Italy       France
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                                    NaN           0              0        0
# 1                         Harry Kane - 6     3031768          47371       64
# 2                    James Rodríguez - 6     3429873          53592       64
# 3  Wesley Sneijder, Thomas Müller... - 5     3178856          49670       64
# 4                     Miroslav Klose - 5     3352605          52384       64

# %%
df4.tail()
# Out:
#     Year         Host  Teams Champion       Runner-Up             TopScorrer  \
# 17  1954  Switzerland     16  Germany         Hungary     Sándor Kocsis - 11
# 18  1950       Brazil     15  Uruguay   United States             Ademir - 8
# 19  1938       France     16    Italy         Hungary           Leônidas - 7
# 20  1934        Italy     16    Italy  Czechoslovakia    Oldřich Nejedlý - 5
# 21  1930      Uruguay     13  Uruguay       Argentina  Guillermo Stábile - 8
#
#     Attendance  AttendanceAvg  Matches
# 17      768607          29562       26
# 18     1045246          47511       22
# 19      375700          20872       18
# 20      363000          21353       17
# 21      590549          32808       18

# %%
# Renombrar columnas : usamos diccionarios siguiendo la estructura  de 'nombre origina' : 'nombre cambiado'

df4.rename(columns = {'Year':'Año'})
# Out:
#      Año                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
# Ahora cambiamos el indice(identificador unipersonal de cada fila)

df4.rename(index= {0 : 300})
# Out:
#      Year                   Host  Teams      Champion       Runner-Up  \
# 300  2022                  Qatar     32           NaN             NaN
# 1    2018                 Russia     32        France         Croatia
# 2    2014                 Brazil     32       Germany       Argentina
# 3    2010           South Africa     32         Spain     Netherlands
# 4    2006                Germany     32         Italy          France
# 5    2002  Korea Republic, Japan     32        Brazil         Germany
# 6    1998                 France     32        France          Brazil
# 7    1994          United States     24        Brazil           Italy
# 8    1990                  Italy     24  West Germany       Argentina
# 9    1986                 Mexico     24     Argentina    West Germany
# 10   1982                  Spain     24         Italy    West Germany
# 11   1978              Argentina     16     Argentina     Netherlands
# ...

# %%
# Filtramos por nombre de la columna.

df4['Host']
# Out:
# 0                     Qatar
# 1                    Russia
# 2                    Brazil
# 3              South Africa
# 4                   Germany
# 5     Korea Republic, Japan
# 6                    France
# 7             United States
# 8                     Italy
# 9                    Mexico
# 10                    Spain
# 11                Argentina
# 12                  Germany
# 13                   Mexico
# 14                  England
# 15                    Chile
# 16                   Sweden
# 17              Switzerland
# 18                   Brazil
# 19                   France
# 20                    Italy
# 21                  Uruguay
# Name: Host, dtype: object

# %%
# Acceso a los elemnetos de in DataFrame en base a las coordenadas (indice y columna)

df6 = df4.iloc[:2,:]
df6
# Out:
#    Year    Host  Teams Champion Runner-Up      TopScorrer  Attendance  \
# 0  2022   Qatar     32      NaN       NaN             NaN           0
# 1  2018  Russia     32   France   Croatia  Harry Kane - 6     3031768
#
#    AttendanceAvg  Matches
# 0              0        0
# 1          47371       64

# %%
# Acceso a los elemnetos de in DataFrame en base a las columnas

df7 = df4.loc[:2,('Host','TopScorrer')]
df7
# Out:
#      Host           TopScorrer
# 0   Qatar                  NaN
# 1  Russia       Harry Kane - 6
# 2  Brazil  James Rodríguez - 6

# %%
df8 = df4.iloc[3:9,1:4]
df8
# Out:
#                     Host  Teams      Champion
# 3           South Africa     32         Spain
# 4                Germany     32         Italy
# 5  Korea Republic, Japan     32        Brazil
# 6                 France     32        France
# 7          United States     24        Brazil
# 8                  Italy     24  West Germany

# %%
df9 = df4.loc[:,'Champion']
print(df9)
# Out:
# 0              NaN
# 1           France
# 2          Germany
# 3            Spain
# 4            Italy
# 5           Brazil
# 6           France
# 7           Brazil
# 8     West Germany
# 9        Argentina
# 10           Italy
# 11       Argentina
# 12    West Germany
# 13          Brazil
# 14         England
# 15          Brazil
# 16          Brazil
# 17         Germany
# 18         Uruguay
# 19           Italy
# 20           Italy
# 21         Uruguay
# Name: Champion, dtype: object

# %%
df10 = df4.loc[df4['Champion'] == 'Brazil']
df10
# Out:
#     Year                   Host  Teams Champion       Runner-Up  \
# 5   2002  Korea Republic, Japan     32   Brazil         Germany
# 7   1994          United States     24   Brazil           Italy
# 13  1970                 Mexico     16   Brazil           Italy
# 15  1962                  Chile     16   Brazil  Czechoslovakia
# 16  1958                 Sweden     16   Brazil          Sweden
#
#                                TopScorrer  Attendance  AttendanceAvg  Matches
# 5                             Ronaldo - 8     2705337          42271       64
# 7      Hristo Stoichkov, Oleg Salenko - 6     3587538          68991       52
# 13                       Gerd Müller - 10     1603975          50124       32
# 15  Leonel Sánchez, Flórián Albert... - 4      893172          27912       32
# 16                     Just Fontaine - 13      819810          23423       35

# %%
df11 = df4.loc[df4['Champion'] == 'Brazil', ['Champion']]
df11
# Out:
#    Champion
# 5    Brazil
# 7    Brazil
# 13   Brazil
# 15   Brazil
# 16   Brazil

# %%
df12 = df4.loc[(df4['Matches'] == 64) & (df4['Champion'] == 'Brazil'), ['Champion']]
df12
# Out:
#   Champion
# 5   Brazil

# %%
df13 = df4.iloc[:2,df4['Champion']:df4['MaTches']]# no se puede poner rangos con str
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MaTches'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dfe = pd.read_csv('/Users/Paco/Downloads/ufo_sighting_data.csv')
dfe
# Out:
# C:\Users\Paco\AppData\Local\Temp\ipykernel_18204\3826726210.py:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfe = pd.read_csv('/Users/Paco/Downloads/ufo_sighting_data.csv')
#               Date_time                  city state/province country  \
# 0      10/10/1949 20:30            san marcos             tx      us
# 1      10/10/1949 21:00          lackland afb             tx     NaN
# 2      10/10/1955 17:00  chester (uk/england)            NaN      gb
# 3      10/10/1956 21:00                  edna             tx      us
# 4      10/10/1960 20:00               kaneohe             hi      us
# ...                 ...                   ...            ...     ...
# 80327    9/9/2013 21:15             nashville             tn      us
# 80328    9/9/2013 22:00                 boise             id      us
# 80329    9/9/2013 22:00                  napa             ca      us
# ...

# %%
dfe1 = dfe.head()
dfe1
# Out:
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# ...

# %%
dfe2 = dfe.loc[(dfe['length_of_encounter_seconds'] == 2700)]

dfe2
# Out:
#              Date_time                                               city  \
# 65750  8/13/2009 21:30                                         chesterton
# 65848  8/13/2013 02:00                                          san diego
# 66152  8/15/1959 15:00                                            roswell
# 66170  8/15/1965 23:00                                             vernon
# 66354  8/15/1988 21:00                                          highlands
# ...                ...                                                ...
# 80131   9/9/1999 23:00  cozumel (mexico) and ocho rios (jamaica) (betw...
# 80169   9/9/2003 05:30                                        rogersville
# 80179   9/9/2003 22:00                                           prescott
# 80229   9/9/2008 20:00                                            el paso
# 80270   9/9/2010 22:00                                        gainesville
#
#       state/province country  UFO_shape length_of_encounter_seconds  \
# ...

# %%
# Añadir nuevas columnas a mi DF a partir de una lista

df4['Favoritos']= pd.Series(['si','no','si','no','si','no','si','no','si'])
df4
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
df4['Favoritos'] = pd.Series(np.random.rand(len(df4)))
df4
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
# DESCARGAR UNA TABLA MODIFICADA



df4.to_csv('tabla_modificada.csv', index=False)

# %%
df4.columns
# Out:
# Index(['Year', 'Host', 'Teams', 'Champion', 'Runner-Up', 'TopScorrer',
#        'Attendance', 'AttendanceAvg', 'Matches', 'Favoritos'],
#       dtype='object')

# %%
# Usa la funcion apply

df4['longitud_char']= df4['TopScorrer'].apply(len)

# %%
print(df4['TopScorrer'])
# Out:
# 0                                       NaN
# 1                            Harry Kane - 6
# 2                       James Rodríguez - 6
# 3     Wesley Sneijder, Thomas Müller... - 5
# 4                        Miroslav Klose - 5
# 5                               Ronaldo - 8
# 6                           Davor Šuker - 6
# 7        Hristo Stoichkov, Oleg Salenko - 6
# 8                   Salvatore Schillaci - 6
# 9                          Gary Lineker - 6
# 10                          Paolo Rossi - 6
# 11                         Mario Kempes - 6
# 12                        Grzegorz Lato - 7
# 13                         Gerd Müller - 10
# 14                              Eusébio - 9
# 15    Leonel Sánchez, Flórián Albert... - 4
# 16                       Just Fontaine - 13
# 17                       Sándor Kocsis - 11
# 18                               Ademir - 8
# 19                             Leônidas - 7
# 20                      Oldřich Nejedlý - 5
# ...

# %%
dfs = df21[['Jugador', 'Goles']] = df4['TopScorrer'].str.split(" - ", expand=True)
dfs
# Out:
#                                     0    1
# 0                                 NaN  NaN
# 1                          Harry Kane    6
# 2                     James Rodríguez    6
# 3   Wesley Sneijder, Thomas Müller...    5
# 4                      Miroslav Klose    5
# 5                             Ronaldo    8
# 6                         Davor Šuker    6
# 7      Hristo Stoichkov, Oleg Salenko    6
# 8                 Salvatore Schillaci    6
# 9                        Gary Lineker    6
# 10                        Paolo Rossi    6
# 11                       Mario Kempes    6
# 12                      Grzegorz Lato    7
# 13                        Gerd Müller   10
# 14                            Eusébio    9
# 15  Leonel Sánchez, Flórián Albert...    4
# 16                      Just Fontaine   13
# 17                      Sándor Kocsis   11
# 18                             Ademir    8
# 19                           Leônidas    7
# 20                    Oldřich Nejedlý    5
# ...

# %%
print(df4)
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32           NaN             NaN
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
data= {'A':['apples','bananas','oranges'],'B':[3,4,5],'C':[6,7,8]}
df = pd.DataFrame(data)
df
# Out:
#          A  B  C
# 0   apples  3  6
# 1  bananas  4  7
# 2  oranges  5  8

# %%
df['A_Longitud'] = df['A'].appply(len)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df['A_Longitud'] = df['A'].appply(len)
#       2 print(df)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'appply'

# %%
data = {'A':[1.232.455.231,23],'B':[3.231.343,45],'C':[6.234.677,45]}
df=pd.DataFrame(data)

#Quiero añadir una columna que me redondee los valores
df['A_Redond']=df['A'].apply(round)
# Out:
#   Cell In[64], line 1
#     data = {'A':[1.232.455.231,23],'B':[3.231.343,45],'C':[6.234.677,45]}
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df = pd.DataFrame({'Name':['Maria','Carlos', 'Carmen'], 'Nacimiento':['05-03-2000','20-05-2001','10-12-1990']})
print(pd.to_datetime(df.Nacimiento,format = '%d-%m-%Y'))
# Out:
# 0   2000-03-05
# 1   2001-05-20
# 2   1990-12-10
# Name: Nacimiento, dtype: datetime64[ns]

# %%
import pandas as pd
df = pd.DataFrame({'Name': ['María','Carlos', 'Carmen'], 'Nacimiento':['05-03-2000','20-05-2001','10-12-1999']})
pd.to_datetime(df.Nacimiento,format = '%d-%m-%Y')
# Out:
# 0   2000-03-05
# 1   2001-05-20
# 2   1999-12-10
# Name: Nacimiento, dtype: datetime64[ns]

# %%
print(df)
# Out:
#      Name  Nacimiento
# 0   Maria  05-03-2000
# 1  Carlos  20-05-2001
# 2  Carmen  10-12-1990
